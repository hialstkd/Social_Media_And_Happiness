# %%
import requests
import pandas as pd
from pprint import pprint
from config import api_key
import time
import json

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
query = "celebrity"

begin_date = "20170328"
end_date = "20170526"

# %%
articles_list = []

for page in range(0, 10):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    time.sleep(1)
    
    for article in articles["response"]["docs"]:
        articles_list.append(article)

# %%
pprint(article)
# Out:
# {'_id': 'nyt://article/87bd311d-b298-5c31-9daf-901a713b26c2',
#  'abstract': 'The Turtle Conservancy, started by Eric Goode, held its annual '
#              'fund-raiser at the Bowery Hotel.',
#  'byline': {'organization': None,
#             'original': 'By Taylor Harris',
#             'person': [{'firstname': 'Taylor',
#                         'lastname': 'Harris',
#                         'middlename': None,
#                         'organization': '',
#                         'qualifier': None,
#                         'rank': 1,
#                         'role': 'reported',
#                         'title': None}]},
#  'document_type': 'article',
#  'headline': {'content_kicker': None,
#               'kicker': 'Party Coverage: Scene City',
#               'main': 'Sarah Silverman, Mark Ruffalo and Edward Norton at '
#                       'Turtle Ball',
#               'name': None,
#               'print_headline': 'A Night for Turtles and Those Who Love Them',
#               'seo': None,
#               'sub': None},
#  'keywords': [{'major': 'N',
#                'name': 'organizations',
#                'rank': 1,
#                'value': 'Turtle Conservancy'},
#               {'major': 'N',
#                'name': 'subject',
#                'rank': 2,
#                'value': 'Turtles and Tortoises'},
#               {'major': 'N',
#                'name': 'subject',
#                'rank': 3,
#                'value': 'Parties (Social)'},
#               {'major': 'N',
#                'name': 'persons',
#                'rank': 4,
#                'value': 'Goode, Eric (1957- )'},
#               {'major': 'N',
#                'name': 'subject',
#                'rank': 5,
#                'value': 'Philanthropy'},
#               {'major': 'N',
#                'name': 'persons',
#                'rank': 6,
#                'value': 'Silverman, Sarah'},
#               {'major': 'N',
#                'name': 'persons',
#                'rank': 7,
#                'value': 'Ruffalo, Mark'}],
#  'lead_paragraph': 'Sarah Silverman looked out at the packed room from the '
#                    'stage on Monday night and smoothed out her pigtailed hair. '
#                    '“You know, animals are vital to this planet,” she said, '
#                    'pausing for effect. “We cannot exist without animals and '
#                    'the ecosystem,” she added, “so even if you have no '
#                    'empathy, even if you’re a sociopath, you should care '
#                    'because this is how you exist.”',
#  'multimedia': [],
#  'news_desk': 'Styles',
#  'print_page': '6',
#  'print_section': 'D',
#  'pub_date': '2017-04-19T19:04:29+0000',
#  'section_name': 'Fashion & Style',
#  'snippet': 'The Turtle Conservancy, started by Eric Goode, held its annual '
#             'fund-raiser at the Bowery Hotel.',
#  'source': 'The New York Times',
#  'type_of_material': 'News',
#  'uri': 'nyt://article/87bd311d-b298-5c31-9daf-901a713b26c2',
#  'web_url': 'https://www.nytimes.com/2017/04/19/fashion/sarah-silverman-mark-ruffalo-edward-norton-turtle-ball.html',
#  'word_count': 479}

# %%
for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]} ')
    print('---------------------------')
# Out:
# A snippet from the article: Deciphering the rise of a lifestyle guru who sells self-absorption as the ultimate luxury product.
# ---------------------------
# A snippet from the article: Before Matt Harvey drowned his sorrows there, the Manhattan nightclub 1 Oak was the site of controversies involving Justin Bieber and Lindsay Lohan.
# ---------------------------
# A snippet from the article: Terry Crews has a line, and so does Ellen DeGeneres. Brad Pitt is at work on his second furniture collection. Kanye West is thinking about Ikea.
# ---------------------------
# A snippet from the article: The singer has gone from fashion plate to fashion force in under five years. But is her success a new paradigm or a paradox?
# ---------------------------
# A snippet from the article: A recent wave of programming offers stars who seemingly stop being polished and get real, even physically uncomfortable. That’s the idea, at least.
# ---------------------------
# A snippet from the article: David Kratz, a former public relations executive and trained as a painter, has helped turn the New York Academy of Art into a hot charity.
# ---------------------------
# A snippet from the article: They don’t call it the Oscars of the East Coast for nothing. See the celebrities who ascended the steps of the Met on Monday night — and what they wore.
# ---------------------------
# A snippet from the article: The shiny, spacey and edgy reigned at the Metropolitan Museum of Art’s Costume Institute Gala. But as loud as the fashions were, some celebrities were mum.
# ---------------------------
# A snippet from the article: The inside scoop on “the party of the year,” from how much it costs to who gets to go and why you should care.
# ---------------------------
# A snippet from the article: Fame is not the only measure at Time magazine’s annual gala, which celebrates activists as well as Hollywood stars.
# ---------------------------
# A snippet from the article: The Pulitzer Prize-winning television critic for The New Yorker joins Jenna Wortham and Wesley Morris to discuss how shows such as “Veep,” “The Handmaid’s Tale” and “The Leftovers” speak to our new political reality.
# ---------------------------
# A snippet from the article: Among Mr. Gallin’s clients were Dolly Parton, Richard Pryor, Cher, Michael Jackson and Joan Rivers, and he became a role model for gays and lesbians in entertainment.
# ---------------------------
# A snippet from the article: No nips, no tucks. Just good old-fashioned facial injections and laser treatments at Dr. Peter Kopelson’s highly discreet beauty shop in Beverly Hills.
# ---------------------------
# A snippet from the article: Royal Caribbean, Celebrity Cruises and Azamara have trips to destinations like Oman (camping in the desert) and Cambodia (Angkor Wat).
# ---------------------------
# A snippet from the article: Chatbots on Facebook Messenger are changing how the music industry connects with listeners, who say they’re happy to hear even from automated versions of their favorite stars.
# ---------------------------
# A snippet from the article: Big entertainment companies have toughened the security of their computer networks. But often, their suppliers and collaborators are vulnerable.
# ---------------------------
# A snippet from the article: Both Geoffrey Zakarian and José Andrés had been sued after they backed out of plans to open restaurants in the Trump International Hotel in Washington.
# ---------------------------
# A snippet from the article: New York’s celebrity elite fete Ms. Midler’s return to Broadway as Dolly Levi.
# ---------------------------
# A snippet from the article: NBC celebrates Red Nose Day in support of poor children around the world with the help of some celebrities, including cast members of “Love Actually.”
# ---------------------------
# A snippet from the article: See which celebrities ascended the steps of the Met on Monday night for the so-called Oscars of the East Coast — and, of course, what they wore.
# ---------------------------
# A snippet from the article: After the main event, which honored Rei Kawakubo, celebrities, museum folk — and die-hard fans of the brand — partied late into the night.
# ---------------------------
# A snippet from the article: Four jewelry experts on the value of celebrity, awards season loans and the moments they’ll never forget.
# ---------------------------
# A snippet from the article: The administration said the entire White House staff would not attend the event next month, in solidarity with the president, who had already said he would not attend.
# ---------------------------
# A snippet from the article: Seth Meyers isn’t surprised Republicans passed a bill without a cost estimate. In November they also supported Donald Trump “without knowing the cost,” he said.
# ---------------------------
# A snippet from the article: Companies occupy real estate at the margins of websites and fill them with links to content landfills, stoking our most primal browsing habits.
# ---------------------------
# A snippet from the article: Even as President Trump heckled the proceedings from Pennsylvania, guests said the often-frivolous White House Correspondents’ Association dinner felt oddly profound.
# ---------------------------
# A snippet from the article: Ryan Milligan returns with a familiar form of wordplay.
# ---------------------------
# A snippet from the article: A clean-cut, patriotic schoolboy image has propelled TFBoys to the top of China’s charts and into the good graces of its Communist leaders.
# ---------------------------
# A snippet from the article: With the president avoiding its annual dinner, the White House Correspondents’ Association gets a chance to drain its own swamp.
# ---------------------------
# A snippet from the article: Former President Bill Clinton and Victor Fleming help us celebrate the 75th anniversary of The New York Times Crossword.
# ---------------------------
# A snippet from the article: Former President Bill Clinton and Victor Fleming help us celebrate the 75th anniversary of The New York Times Crossword.
# ---------------------------
# A snippet from the article: New York’s celebrity elite feted Ms. Midler’s return to Broadway as Dolly Levi.
# ---------------------------
# A snippet from the article: The Friday puzzle resulted from a collaboration between former President Bill Clinton and Victor Fleming, an Arkansas district court judge.
# ---------------------------
# A snippet from the article: “Unbreakable Kimmy Schmidt” returns for a third season and sends its heroine to college. And “American Masters” celebrates the culinary legacy of Mr. Beard.
# ---------------------------
# A snippet from the article: More notable chefs and restaurateurs than ever are heading to the area, among them Galen Zamarra of Mas (Farmhouse) in Manhattan, Frank DeCarlo of Peasant, and Philippe Delgrange of Le Bilboquet.
# ---------------------------
# A snippet from the article: This word has appeared in 120 articles on nytimes.com in the past year.
# ---------------------------
# A snippet from the article: A man has trouble getting his wife’s attention when he sees someone famous on a Greenwich Village street.
# ---------------------------
# A snippet from the article: His name was Walter Winchell, and he presided over Table 50 of the Stork Club, temple of a new cult of celebrity, in mid-20th-century Manhattan.
# ---------------------------
# A snippet from the article: A new show on Nat Geo focuses on Einstein’s life in physics, and his physical life, too.
# ---------------------------
# A snippet from the article: The 7-year-old, now a refugee in Turkey, hopes her book, to be published by Simon & Schuster, will “bring peace to children all over the world.”
# ---------------------------
# A snippet from the article: Known for a dramatic style that challenges stereotypes about her home country, the photographer was recently honored at a gala in New York.
# ---------------------------
# A snippet from the article: The cable channel has long been a preshow destination for awards programs on other networks. Now it’s betting it can draw viewers to its own event.
# ---------------------------
# A snippet from the article: A celebrity lawyer representing a ticket buyer filed suit after a luxury musical weekend in the Bahamas fell apart. Organizers said, “We were simply in over our heads.”
# ---------------------------
# A snippet from the article: Elements such as the blanket of roses for the winner and the iconic glasses for mint juleps combine to make this the sport’s key annual event.
# ---------------------------
# A snippet from the article: “Live With Kelly and Ryan” will face an aggressive ratings push in the fall from NBC, which will put Megyn Kelly in the 9 a.m. weekday slot that Ms. Ripa has long dominated.
# ---------------------------
# A snippet from the article: Though this documentary looks at the artist and his work, it is more concerned with layering on the admiration.
# ---------------------------
# A snippet from the article: His raw monologue about health care and nearly losing his newborn son shows the power of hearing a message from a usually apolitical host.
# ---------------------------
# A snippet from the article: Matthew Henson, a former fashion editor, is making his name as a celebrity stylist. Now if only his parents could figure out what he does for a living.
# ---------------------------
# A snippet from the article: To kick off next month’s Wear Orange campaign, designers and celebrities are lending star power to the gun safety cause.
# ---------------------------
# A snippet from the article: Alexi Pappas, a runner who, in real life, competed at the 2016 Olympics, helped write, direct and produce — and stars in — a film about a runner.
# ---------------------------
# A snippet from the article: Lydia Tenaglia’s documentary is a portrait of Mr. Tower, a force behind the California Cuisine movement in the 1970s, among other culinary feats.
# ---------------------------
# A snippet from the article: The Public and National theaters plan to stage the documentary play “All the President’s Men?” for one night at the Town Hall.
# ---------------------------
# A snippet from the article: Ahead of his June court date, Bill Cosby and his daughter made rare public statements. But his spokesman denies a public relations campaign.
# ---------------------------
# A snippet from the article: Through the program Publicolor, students at P.S. 244 will paint a mural based on the artist’s 1952 work “Untitled.”
# ---------------------------
# A snippet from the article: Paul Surridge, a behind-the-scenes talent most recently at Z Zegna, will take over the Italian fashion house.
# ---------------------------
# A snippet from the article: Mr. Murphy is best known for a skit in which he would spoof himself, regaling viewers with stories of his encounters with celebrities like Rick James.
# ---------------------------
# A snippet from the article: The map will be sold on June 25 at Van Eaton Galleries in Sherman Oaks, Calif., and could fetch between $750,000 and $1 million.
# ---------------------------
# A snippet from the article: Alexandre Daillance, a college sophomore, started the Instagram-friendly streetwear label NasaSeasons, worn by many celebrities.
# ---------------------------
# A snippet from the article: Our Top 10 Comments of the Week: Readers debate the health care vote, “lunch shaming” and whether cats are capable of loving humans.
# ---------------------------
# A snippet from the article: Artists and brands are collaborating on advertisements that move away from mere product placement, a practice so common that the Tribeca Film Festival has an award for it.
# ---------------------------
# A snippet from the article: This is the first year that the British Fashion Council/Vogue Designer Fashion Fund award, announced on Tuesday, went to more than one label.
# ---------------------------
# A snippet from the article: There is a growing category of trips where you can mingle with stars and unleash your inner fan.
# ---------------------------
# A snippet from the article: The 61-year-old actress stars in “The Lovers,” a dour romantic comedy about marriage and affairs.
# ---------------------------
# A snippet from the article: From Kendall Jenner to the Fyre Festival, the risks of being a tastemaker have been exposed.
# ---------------------------
# A snippet from the article: The City Council of North Bay, Ontario, abandoned a plan to move the house to a community with no direct connection to the Dionne quintuplets’ story.
# ---------------------------
# A snippet from the article: Mr. Goncalves took his love of online shopping and opened a boutique devoted to gender-blurring fashions.
# ---------------------------
# A snippet from the article: Thinking caps on! See how closely you’ve kept an eye on our commander in chief so far.
# ---------------------------
# A snippet from the article: The singer-songwriter’s new album is a low-fi exploration of extreme emotions. How does it relate to her earlier hits, and how did she get here? A panel discussion, on Popcast.
# ---------------------------
# A snippet from the article: In seven years, the identical twins Drew and Jonathan Scott, 39, have gone from aspiring celebrities on a small Canadian cable network to HGTV headliners.
# ---------------------------
# A snippet from the article: Two Times pieces ahead of the ceremony attracted scorn on social media, but were also widely popular. For the wedding itself, coverage involved a series of photographs.
# ---------------------------
# A snippet from the article: C.P. Lacey is starting his 30th year as the most feared character at Amateur Night: A tap-dancing dream killer who shoos booed contestants off stage.
# ---------------------------
# A snippet from the article: This comedian’s well-known targets included Bob Hope, Frank Sinatra and Howard Stern.
# ---------------------------
# A snippet from the article: Two Times pieces ahead of the ceremony attracted scorn on social media, but were also widely popular. For the wedding itself, coverage involved a series of photographs.
# ---------------------------
# A snippet from the article: This good-natured York Theater Company musical matches a jilted bride and a restaurant worker with big dreams.
# ---------------------------
# A snippet from the article: Pick-me-ups to help get us into a summer mind-set while we wait for the temperature to catch up.
# ---------------------------
# A snippet from the article: There are two special House elections coming up. Should Republicans be worried?
# ---------------------------
# A snippet from the article: The personal injury law firm was famous for its infectious jingle.
# ---------------------------
# A snippet from the article: The Grammy-winning classical pianist Emanuel Ax teams up with the veteran puzzle constructor Brad Wilber to offer us a puzzle that sings.
# ---------------------------
# A snippet from the article: Pitched as a conservative alternative to Teen Vogue and Seventeen, it mixes tips on fashion and abstinence with profiles of Christian stars.
# ---------------------------
# A snippet from the article: Jimmy Kimmel wondered whether President Trump thought the Easter Egg Roll “was a menu item at P. F. Chang’s.”
# ---------------------------
# A snippet from the article: The company said it would remain independent and would pursue its strategic plan of digital growth and new revenue opportunities.
# ---------------------------
# A snippet from the article: Three writers offer a defense of the state.
# ---------------------------
# A snippet from the article: The former Fox News anchor is set to return to television with a Sunday evening newsmagazine and then a morning show scheduled for the fall.
# ---------------------------
# A snippet from the article: Pitched as a conservative alternative to Teen Vogue and Seventeen, it mixes tips on fashion and abstinence with profiles of Christian stars.
# ---------------------------
# A snippet from the article: China’s commitment to shut down its domestic ivory trade this year has helped depress demand for ivory.
# ---------------------------
# A snippet from the article: The Grammy-winning classical pianist Emanuel Ax teams up with the veteran puzzle constructor Brad Wilber to offer us a puzzle that sings.
# ---------------------------
# A snippet from the article: He’s a rapper, a social media phenomenon, the guy yelling “ya” on Migos’s hit “Bad and Boujee.” What’s the secret of Uzi’s success? A panel discussion, on Popcast.
# ---------------------------
# A snippet from the article: The work that won the National Book Award will be staged in a multimedia production in April 2018.
# ---------------------------
# A snippet from the article: The company posted its first decline in revenue since its initial public offering in 2013, but its results still beat investors’ low expectations.
# ---------------------------
# A snippet from the article: Two episodes, encompassing the mystical and the silly.
# ---------------------------
# A snippet from the article: At the party of the year, the guest of honor was a somewhat elusive presence.
# ---------------------------
# A snippet from the article: It just might be the most exciting eight questions in sports.
# ---------------------------
# A snippet from the article: Our guide to new art shows, and some that will be closing soon.
# ---------------------------
# A snippet from the article: The singer-songwriter will join a long list of musicians who have taken part in the show. How did her predecessors fare?
# ---------------------------
# A snippet from the article: John Cena proposed marriage to Nikki Bella, and the Undertaker found the exit at the annual entertainment event.
# ---------------------------
# A snippet from the article: Navigate the red carpet with E! at one of the year’s hottest tickets: the Met Gala. Or prepare for the final season of the Showtime comedy “Episodes.”
# ---------------------------
# A snippet from the article: “Genius” traverses Einstein’s brilliant mind and lusty pursuits. And “Great News,” with “30 Rock” in its DNA, navigates a relationship.
# ---------------------------
# A snippet from the article: The cult novel “I Love Dick” gets the series treatment from Jill Soloway. “Master of None” moves to Italy. And “Anne of Green Gables” goes darker.
# ---------------------------
# A snippet from the article: “Girlboss” loosely chronicles the rise of the e-commerce diva Sophia Amoruso. And Caitlyn Jenner talks with Diane Sawyer about her new memoir.
# ---------------------------
# A snippet from the article: The Turtle Conservancy, started by Eric Goode, held its annual fund-raiser at the Bowery Hotel.
# ---------------------------

# %%
# for article in articles_list:
#     pprint(f'keywords from the article: {article["keywords"]} ')
#     print('---------------------------')

# %%
# for article in articles_list:
#     print(f'Publication date from the article: {article["pub_date"]} ')
#     print('---------------------------')

# %%
# for article in articles_list:
#     pprint(f'Categorized as news from: {article["section_name"]} ')
#     print('---------------------------')

# %%
# article["keywords"][0]

# %%
keyword_articles = pd.DataFrame(article["keywords"])
keyword_articles
# Out:
#             name                  value  rank major
# 0  organizations     Turtle Conservancy     1     N
# 1        subject  Turtles and Tortoises     2     N
# 2        subject       Parties (Social)     3     N
# 3        persons   Goode, Eric (1957- )     4     N
# 4        subject           Philanthropy     5     N
# 5        persons       Silverman, Sarah     6     N
# 6        persons          Ruffalo, Mark     7     N
