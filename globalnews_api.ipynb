# %%
import requests
import pandas as pd
from pprint import pprint
from config import api_key
import time
import json

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
query = "global news"

begin_date = "20170328"
end_date = "20170526"

# %%
articles_list = []

for page in range(0, 10):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    time.sleep(1)
    
    for article in articles["response"]["docs"]:
        articles_list.append(article)

# %%
pprint(article)
# Out:
# {'_id': 'nyt://article/a058c27b-65ce-58d1-a4e2-b7edcfe2425d',
#  'abstract': 'Here’s what you need to know to start your day.',
#  'byline': {'organization': None,
#             'original': 'By Charles McDermid',
#             'person': [{'firstname': 'Charles',
#                         'lastname': 'McDermid',
#                         'middlename': None,
#                         'organization': '',
#                         'qualifier': None,
#                         'rank': 1,
#                         'role': 'reported',
#                         'title': None}]},
#  'document_type': 'article',
#  'headline': {'content_kicker': None,
#               'kicker': 'Asia and Australia Edition',
#               'main': 'Rodrigo Duterte, Pope Francis, Delta: Your Morning '
#                       'Briefing',
#               'name': None,
#               'print_headline': None,
#               'seo': None,
#               'sub': None},
#  'keywords': [],
#  'lead_paragraph': 'Good morning. ',
#  'multimedia': [{'caption': None,
#                  'credit': None,
#                  'crop_name': 'hpLarge',
#                  'height': 287,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'hpLarge',
#                  'subtype': 'hpLarge',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-hpLarge-v2.jpg',
#                  'width': 511},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeWidescreen573',
#                  'height': 322,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeWidescreen573',
#                  'subtype': 'largeWidescreen573',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-largeWidescreen573-v2.jpg',
#                  'width': 573},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeWidescreen1050',
#                  'height': 590,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeWidescreen1050',
#                  'subtype': 'largeWidescreen1050',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-largeWidescreen1050-v2.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'watch308',
#                  'height': 348,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'watch308',
#                  'subtype': 'watch308',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-watch308-v2.jpg',
#                  'width': 312},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'watch268',
#                  'height': 303,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'watch268',
#                  'subtype': 'watch268',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-watch268-v2.jpg',
#                  'width': 272},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'sfSpan',
#                  'height': 263,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'sfSpan',
#                  'subtype': 'sfSpan',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-sfSpan-v2.jpg',
#                  'width': 395},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeHorizontalJumbo',
#                  'height': 683,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeHorizontalJumbo',
#                  'subtype': 'largeHorizontalJumbo',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-largeHorizontalJumbo-v2.jpg',
#                  'width': 1024},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeHorizontal375',
#                  'height': 250,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeHorizontal375',
#                  'subtype': 'largeHorizontal375',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-largeHorizontal375-v2.jpg',
#                  'width': 375},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoFifteenBySeven1305',
#                  'height': 609,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoFifteenBySeven1305',
#                  'subtype': 'videoFifteenBySeven1305',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoFifteenBySeven1305-v2.jpg',
#                  'width': 1305},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoFifteenBySeven2610',
#                  'height': 1218,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoFifteenBySeven2610',
#                  'subtype': 'videoFifteenBySeven2610',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoFifteenBySeven2610-v2.jpg',
#                  'width': 2610},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'miniMoth',
#                  'height': 70,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'miniMoth',
#                  'subtype': 'miniMoth',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-miniMoth-v2.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'windowsTile336H',
#                  'height': 336,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'windowsTile336H',
#                  'subtype': 'windowsTile336H',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-windowsTile336H-v2.jpg',
#                  'width': 694},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'verticalTwoByThree735',
#                  'height': 1103,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'verticalTwoByThree735',
#                  'subtype': 'verticalTwoByThree735',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-verticalTwoByThree735-v2.jpg',
#                  'width': 735},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'articleLarge',
#                  'height': 400,
#                  'legacy': {'xlarge': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-articleLarge.jpg',
#                             'xlargeheight': 400,
#                             'xlargewidth': 600},
#                  'rank': 0,
#                  'subType': 'xlarge',
#                  'subtype': 'xlarge',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-articleLarge.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog480',
#                  'height': 320,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog480',
#                  'subtype': 'blog480',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-blog480.jpg',
#                  'width': 480},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog427',
#                  'height': 285,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog427',
#                  'subtype': 'blog427',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-blog427.jpg',
#                  'width': 427},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'tmagArticle',
#                  'height': 395,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'tmagArticle',
#                  'subtype': 'tmagArticle',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-tmagArticle.jpg',
#                  'width': 592},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'jumbo',
#                  'height': 683,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'jumbo',
#                  'subtype': 'jumbo',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-jumbo.jpg',
#                  'width': 1024},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog225',
#                  'height': 150,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog225',
#                  'subtype': 'blog225',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-blog225.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master675',
#                  'height': 450,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master675',
#                  'subtype': 'master675',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-master675.jpg',
#                  'width': 675},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master180',
#                  'height': 120,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master180',
#                  'subtype': 'master180',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-master180.jpg',
#                  'width': 180},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master768',
#                  'height': 512,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master768',
#                  'subtype': 'master768',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-master768.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'popup',
#                  'height': 433,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'popup',
#                  'subtype': 'popup',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-popup.jpg',
#                  'width': 650},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog533',
#                  'height': 355,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog533',
#                  'subtype': 'blog533',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-blog533.jpg',
#                  'width': 533},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'tmagSF',
#                  'height': 241,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'tmagSF',
#                  'subtype': 'tmagSF',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-tmagSF.jpg',
#                  'width': 362},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'slide',
#                  'height': 400,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'slide',
#                  'subtype': 'slide',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-slide.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'superJumbo',
#                  'height': 1365,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'superJumbo',
#                  'subtype': 'superJumbo',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-superJumbo.jpg',
#                  'width': 2048},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master1050',
#                  'height': 700,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master1050',
#                  'subtype': 'master1050',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-master1050.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master495',
#                  'height': 330,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master495',
#                  'subtype': 'master495',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-master495.jpg',
#                  'width': 495},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master315',
#                  'height': 210,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master315',
#                  'subtype': 'master315',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-master315.jpg',
#                  'width': 315},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbWide',
#                  'height': 126,
#                  'legacy': {'wide': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-thumbWide-v2.jpg',
#                             'wideheight': 126,
#                             'widewidth': 190},
#                  'rank': 0,
#                  'subType': 'wide',
#                  'subtype': 'wide',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-thumbWide-v2.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoThumb',
#                  'height': 50,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoThumb',
#                  'subtype': 'videoThumb',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoThumb-v2.jpg',
#                  'width': 75},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoLarge',
#                  'height': 507,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoLarge',
#                  'subtype': 'videoLarge',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoLarge-v2.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo210',
#                  'height': 140,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo210',
#                  'subtype': 'mediumThreeByTwo210',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-mediumThreeByTwo210-v2.jpg',
#                  'width': 210},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo225',
#                  'height': 150,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo225',
#                  'subtype': 'mediumThreeByTwo225',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-mediumThreeByTwo225-v2.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo440',
#                  'height': 293,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo440',
#                  'subtype': 'mediumThreeByTwo440',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-mediumThreeByTwo440-v2.jpg',
#                  'width': 440},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo252',
#                  'height': 168,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo252',
#                  'subtype': 'mediumThreeByTwo252',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-mediumThreeByTwo252-v2.jpg',
#                  'width': 252},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo378',
#                  'height': 252,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo378',
#                  'subtype': 'mediumThreeByTwo378',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-mediumThreeByTwo378-v2.jpg',
#                  'width': 378},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSmall',
#                  'height': 281,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSmall',
#                  'subtype': 'videoSmall',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSmall-v2.jpg',
#                  'width': 500},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoHpMedium',
#                  'height': 211,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoHpMedium',
#                  'subtype': 'videoHpMedium',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoHpMedium-v2.jpg',
#                  'width': 375},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine600',
#                  'height': 338,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine600',
#                  'subtype': 'videoSixteenByNine600',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine600-v2.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine540',
#                  'height': 304,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine540',
#                  'subtype': 'videoSixteenByNine540',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine540-v2.jpg',
#                  'width': 540},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine495',
#                  'height': 278,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine495',
#                  'subtype': 'videoSixteenByNine495',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine495-v2.jpg',
#                  'width': 495},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine390',
#                  'height': 219,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine390',
#                  'subtype': 'videoSixteenByNine390',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine390-v2.jpg',
#                  'width': 390},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine480',
#                  'height': 270,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine480',
#                  'subtype': 'videoSixteenByNine480',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine480-v2.jpg',
#                  'width': 480},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine310',
#                  'height': 174,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine310',
#                  'subtype': 'videoSixteenByNine310',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine310-v2.jpg',
#                  'width': 310},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine225',
#                  'height': 126,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine225',
#                  'subtype': 'videoSixteenByNine225',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine225-v2.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine96',
#                  'height': 54,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine96',
#                  'subtype': 'videoSixteenByNine96',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine96-v2.jpg',
#                  'width': 96},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine768',
#                  'height': 432,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine768',
#                  'subtype': 'videoSixteenByNine768',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine768-v2.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine150',
#                  'height': 84,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine150',
#                  'subtype': 'videoSixteenByNine150',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine150-v2.jpg',
#                  'width': 150},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine1050',
#                  'height': 591,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine1050',
#                  'subtype': 'videoSixteenByNine1050',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine1050-v2.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine3000',
#                  'height': 1687,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine3000',
#                  'subtype': 'videoSixteenByNine3000',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNine3000-v2.jpg',
#                  'width': 3000},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNineJumbo1600',
#                  'height': 900,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNineJumbo1600',
#                  'subtype': 'videoSixteenByNineJumbo1600',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-videoSixteenByNineJumbo1600-v2.jpg',
#                  'width': 1600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'articleInline',
#                  'height': 127,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'articleInline',
#                  'subtype': 'articleInline',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-articleInline-v2.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'hpSmall',
#                  'height': 109,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'hpSmall',
#                  'subtype': 'hpSmall',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-hpSmall-v2.jpg',
#                  'width': 163},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blogSmallInline',
#                  'height': 101,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blogSmallInline',
#                  'subtype': 'blogSmallInline',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-blogSmallInline-v2.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumFlexible177',
#                  'height': 116,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumFlexible177',
#                  'subtype': 'mediumFlexible177',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-mediumFlexible177-v3.gif',
#                  'width': 177},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'facebookJumbo',
#                  'height': 550,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'facebookJumbo',
#                  'subtype': 'facebookJumbo',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-facebookJumbo-v2.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'square320',
#                  'height': 320,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'square320',
#                  'subtype': 'square320',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-square320-v2.jpg',
#                  'width': 320},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'filmstrip',
#                  'height': 190,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'filmstrip',
#                  'subtype': 'filmstrip',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-filmstrip-v2.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'square640',
#                  'height': 640,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'square640',
#                  'subtype': 'square640',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-square640-v2.jpg',
#                  'width': 640},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'moth',
#                  'height': 151,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'moth',
#                  'subtype': 'moth',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-moth-v2.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumSquare149',
#                  'height': 149,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumSquare149',
#                  'subtype': 'mediumSquare149',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-mediumSquare149-v2.jpg',
#                  'width': 149},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbStandard',
#                  'height': 75,
#                  'legacy': {'thumbnail': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-thumbStandard-v2.jpg',
#                             'thumbnailheight': 75,
#                             'thumbnailwidth': 75},
#                  'rank': 0,
#                  'subType': 'thumbnail',
#                  'subtype': 'thumbnail',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-thumbStandard-v2.jpg',
#                  'width': 75},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbLarge',
#                  'height': 150,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'thumbLarge',
#                  'subtype': 'thumbLarge',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-thumbLarge-v2.jpg',
#                  'width': 150},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'smallSquare252',
#                  'height': 252,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'smallSquare252',
#                  'subtype': 'smallSquare252',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-smallSquare252-v2.jpg',
#                  'width': 252},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blogSmallThumb',
#                  'height': 50,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blogSmallThumb',
#                  'subtype': 'blogSmallThumb',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-blogSmallThumb-v2.jpg',
#                  'width': 50},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'smallSquare168',
#                  'height': 168,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'smallSquare168',
#                  'subtype': 'smallSquare168',
#                  'type': 'image',
#                  'url': 'images/2017/04/30/briefing/01BRIEFING-asia-slide-BO7C/01BRIEFING-asia-slide-BO7C-smallSquare168-v2.jpg',
#                  'width': 168}],
#  'news_desk': 'NYTNow',
#  'pub_date': '2017-04-30T19:51:22+0000',
#  'section_name': 'Briefing',
#  'snippet': 'Here’s what you need to know to start your day.',
#  'source': 'The New York Times',
#  'type_of_material': 'briefing',
#  'uri': 'nyt://article/a058c27b-65ce-58d1-a4e2-b7edcfe2425d',
#  'web_url': 'https://www.nytimes.com/2017/04/30/briefing/rodrigo-duterte-pope-francis-delta.html',
#  'word_count': 1167}

# %%
for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]} ')
    print('---------------------------')
# Out:
# A snippet from the article: The rosy forecast is a change for the fund, which has been fairly downbeat in recent years about the global economy’s capacity to deliver sustained growth.
# ---------------------------
# A snippet from the article: After President Xi Jinping went to Mar-a-Lago, Chinese state-controlled news outlets offered some hints about how the visit was perceived back home.
# ---------------------------
# A snippet from the article: The HNA Group was transformed into a global powerhouse through an array of acquisitions and investments that were supported by Chinese state banks.
# ---------------------------
# A snippet from the article: By a new metric that takes into account economic means, some countries are making surprising gains in health, while the United States lags behind.
# ---------------------------
# A snippet from the article: A regulator will rule next month on whether 21st Century Fox can buy the rest of Sky, the British satellite and news giant.
# ---------------------------
# A snippet from the article: The South Pacific nation has recently been running a municipal program to lure more coders and engineers from the United States and around the world.
# ---------------------------
# A snippet from the article: The risk is that investors won’t send the signals that might prevent political leaders from making big mistakes.
# ---------------------------
# A snippet from the article: The removal of a co-president, a holdover from the Roger Ailes era, continued a housecleaning prompted by a sexual harassment scandal.
# ---------------------------
# A snippet from the article: Computer scientists and tech giants are using algorithms and online data to spot misinformation faster than traditional fact-checkers can.
# ---------------------------
# A snippet from the article: Beijing’s relative silence may be an attempt to placate both Kim Jong-un of North Korea and President Trump, and to prevent the Chinese public from panicking.
# ---------------------------
# A snippet from the article: The sculptor Arturo Di Modica said Wall Street’s bronze girl, meant to symbolize female empowerment, distorts the meaning of his work.
# ---------------------------
# A snippet from the article: The former New Jersey governor is trying to shake off the failure of MF Global to start a hedge fund designed to take advantage of turmoil in the Trump era.
# ---------------------------
# A snippet from the article: Mark Zuckerberg now acknowledges the dangerous side of the social revolution he helped start. But is the most powerful tool for connection in human history capable of adapting to the world it created?
# ---------------------------
# A snippet from the article: Here are some of the voices of those central to environmental policy who have denied the effects of human-caused climate change.
# ---------------------------
# A snippet from the article: Guo Wengui, an outspoken Chinese-born billionaire whom China views as a criminal, has alarmed Beijing with his public denunciations.
# ---------------------------
# A snippet from the article: Taiwan’s president and ministers want the self-ruled island to have observer status at the World Health Assembly’s annual meeting in Geneva.
# ---------------------------
# A snippet from the article: The so-called Thaad system, deployed over China’s objections as a defense against North Korea, will soon go into “actual operation,” a South Korean official said.
# ---------------------------
# A snippet from the article: Two prestigious Chinese universities, a movie theater chain in South Korea and Japanese automakers were affected, but copycat variants did not seem to have materialized.
# ---------------------------
# A snippet from the article: A commentary carried by the North’s official news agency said the country would not halt its nuclear program, even if it risked its friendly relationship with China.
# ---------------------------
# A snippet from the article: A Foreign Ministry spokeswoman would not confirm or deny a New York Times report that more than a dozen C.I.A. informants were killed or imprisoned.
# ---------------------------
# A snippet from the article: A Foreign Ministry spokeswoman would not confirm or deny a New York Times report that more than a dozen C.I.A. informants were killed or imprisoned.
# ---------------------------
# A snippet from the article: The state has been at the leading edge of the resistance to President Trump. But of all the battles, none have the global implications of climate change.
# ---------------------------
# A snippet from the article: Geoengineering, providing methods to offset climate change by applying scientific fixes rather than changing old habits, may have found its moment.
# ---------------------------
# A snippet from the article: The country was hit the hardest in the first wave of a global hacking effort, with banks, cellphone operators and railroads fending off attacks.
# ---------------------------
# A snippet from the article: International firms still fear retaliation but are escalating their behind-the-scenes rhetoric as China becomes a more difficult business environment.
# ---------------------------
# A snippet from the article: The deal would bolster the size of Cowen’s sales and trading business and give it a greater global reach.
# ---------------------------
# A snippet from the article: The “ransomware” attacks across continents raised fears that people would not be able to meet ransom demands before their data were destroyed.
# ---------------------------
# A snippet from the article: The expansion of the so-called gag rule, which bars aid to health organizations worldwide that provide or discuss abortion services, would also sweep up groups that fight AIDS and malaria.
# ---------------------------
# A snippet from the article: Scientists compiling a record of the atmosphere based on air trapped in Antarctic ice found that rising carbon dioxide has accelerated plant growth.
# ---------------------------
# A snippet from the article: Donations were up for the fund-raising campaign in 2016-17, as the fund again showed how even modest giving can greatly improve lives.
# ---------------------------
# A snippet from the article: The turnaround will be driven in part by the fact that the world’s Christian population is relatively old, while the Muslim population is younger and concentrated in regions with high fertility rates.
# ---------------------------
# A snippet from the article: Donations were up for the fund-raising campaign in 2016-17, as the fund again showed how even modest giving can greatly improve lives.
# ---------------------------
# A snippet from the article: Few people know the struggle and angst that put two Chinese characters at the top of our home page.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Readers respond.
# ---------------------------
# A snippet from the article: Please join us for a discussion of how we documented private sponsorship — and what can be learned from Canada’s approach.
# ---------------------------
# A snippet from the article: Trump’s promise to do away with Obama’s legacy on climate change, and Theresa May’s farewell to the European Union.
# ---------------------------
# A snippet from the article: Mr. Barber’s 1995 book presciently analyzed the forces leading to the Sept. 11, 2001, attacks and the rise in tribalism around the world.
# ---------------------------
# A snippet from the article: President Vladimir V. Putin has called repeatedly for unity in fighting terrorism. President Trump seemed to take up that call, at least momentarily, on Tuesday.
# ---------------------------
# A snippet from the article: The social media network is struggling with its role in policing content on its global platform.
# ---------------------------
# A snippet from the article: A prominent Chinese state-run newspaper warned the North that it faced a cutoff of vital oil supplies if it dared test a nuclear weapon.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: The former Fox News chief expanded the reach of conservative media — and paved the way to its decline.
# ---------------------------
# A snippet from the article: Global markets sagged as investors appeared to lose confidence in the U.S. president’s agenda.
# ---------------------------
# A snippet from the article: Czech officials reacted with outrage at a comment by President Milos Zeman, who was speaking with Russia’s president in Beijing.
# ---------------------------
# A snippet from the article: After broadcasting himself dangling the girl by the neck from a building on the resort island of Phuket, the man killed himself, the police said.
# ---------------------------
# A snippet from the article: Many in France are taking the size of Emmanuel Macron’s big lead in the race for president as a sign that voters there will not spring another surprise.
# ---------------------------
# A snippet from the article: In stark contrast to President Trump’s “America First” mantra, the “One Belt, One Road” plan aims to remake global commerce in China’s image.
# ---------------------------
# A snippet from the article: Social media has been abuzz with images of Mr. Trump joining Saudi and Egyptian leaders in laying hands on a white sphere.
# ---------------------------
# A snippet from the article: A video shared by the city’s crown prince says that “expression knows no boundaries or limits,” but within the United Arab Emirates that is not the case.
# ---------------------------
# A snippet from the article: In “Easternization,” Gideon Rachman explores an international transfer of power.
# ---------------------------
# A snippet from the article: The president has groused to friends that he is not looking forward to leaving, and his preparation for his first foreign excursion in office has been hit-or-miss.
# ---------------------------
# A snippet from the article: The catastrophe set off an unexpected shortage of iodine, leaving children in faraway countries vulnerable to cognitive deficits.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Fame is not the only measure at Time magazine’s annual gala, which celebrates activists as well as Hollywood stars.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: The North warned that the missile, which landed in the sea between the North and Japan, could reach American military bases in the Pacific.
# ---------------------------
# A snippet from the article: Under a new hire, Chris Gaertner, the office plans to focus on how technology is altering existing business.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: The president’s daughter, now a White House adviser, has filed 173 foreign trademarks in 21 countries, as well as in Hong Kong and the European Union.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: The announcement came after a meeting at Buckingham Palace that touched off alarms about the health of Queen Elizabeth II and her husband, who is 95.
# ---------------------------
# A snippet from the article: Ignoring climate change and the benefits of clean energy only helps a rival.
# ---------------------------
# A snippet from the article: After a number of setbacks, the former New Jersey governor and Goldman Sachs executive is planning his next act: a hedge fund built for the Trump era.
# ---------------------------
# A snippet from the article: Manhattan chefs head for the Hamptons, Jean-Georges Vongerichten at the Public Hotel, and other restaurant news.
# ---------------------------
# A snippet from the article: We’re following major developments in the markets throughout the day. Check here for the latest updates.
# ---------------------------
# A snippet from the article: While the American far right has undertaken a digital assault in support of Marine Le Pen, it hasn’t resonated with the French electorate.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: We’re following major developments in the markets throughout the day. Check here for the latest updates.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: The transaction would create a chemicals company with a combined market value of about $14 billion and comes as the industry consolidates to gain scale and reduce costs.
# ---------------------------
# A snippet from the article: The lawsuit said that Chobani has suffered after a report on InfoWars connecting the factory with a child sexual assault because it involved refugees, whom Chobani has made a policy of hiring.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: A new breed of television shows fits right in with the current environment of fake news, gaslighting and contested objectivity.
# ---------------------------
# A snippet from the article: The talks are at an early stage, but a deal would make Glencore a large player in the United States agricultural commodities market.
# ---------------------------
# A snippet from the article: Many women remain skeptical that they will be heard if they come forward with tales of inappropriate workplace behavior. But the power women wield outside their own offices may help even the game.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: The bank said it would retain full ownership of its Swiss unit and would raise additional capital through a share sale as it continued restructuring.
# ---------------------------
# A snippet from the article: The release of the girls is by far the biggest breakthrough in the mass abduction of nearly 300 Nigerian schoolgirls.
# ---------------------------
# A snippet from the article: A regulatory standard complicates a bid by Rupert Murdoch and his family, owners of the scandal-plagued Fox News, to gain complete control of the Sky satellite and cable network.
# ---------------------------
# A snippet from the article: For years, the United States pushed China to commit to limiting its use of fossil fuels. The countries now look likely to switch roles.
# ---------------------------
# A snippet from the article: Smallpox was eradicated globally four decades ago. That awe-inspiring triumph has long begged to be duplicated. Yet to date, it stands alone.
# ---------------------------
# A snippet from the article: Azam Ahmed, who is bureau chief for Mexico, Central America and the Caribbean, says the new spotlight on Mexico has helped reveal its contradictions.
# ---------------------------
# A snippet from the article: As Ethiopia’s health minister, Tedros Adhanom Ghebreyesus ignored cholera outbreaks, a global health expert and adviser to a rival candidate charges.
# ---------------------------
# A snippet from the article: Azam Ahmed, who is bureau chief for Mexico, Central America and the Caribbean, says the new spotlight on Mexico has helped reveal its contradictions.
# ---------------------------
# A snippet from the article: The attacks amounted to an audacious global blackmail attempt spread by the internet, and underscored the vulnerabilities of the digital age.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: The Australian city may not seem to rank as a top food destinations, but its marketing offensive was first-rate.
# ---------------------------
# A snippet from the article: As Ethiopia’s health minister, Tedros Adhanom Ghebreyesus ignored cholera outbreaks, a global health expert and adviser to a rival candidate charges.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: In his first public foray abroad since leaving office, Mr. Obama linked climate and food issues and met with Matteo Renzi, the former Italian prime minister seeking a comeback.
# ---------------------------
# A snippet from the article: Western cybersecurity researchers have identified the man being held, Peter Levashov, as the spammer known as Peter Severa, though some doubt he is the same person.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------

# %%
# for article in articles_list:
#     pprint(f'keywords from the article: {article["keywords"]} ')
#     print('---------------------------')

# %%
# for article in articles_list:
#     print(f'Publication date from the article: {article["pub_date"]} ')
#     print('---------------------------')

# %%
# for article in articles_list:
#     pprint(f'Categorized as news from: {article["section_name"]} ')
#     print('---------------------------')

# %%
# article["keywords"][0]

# %%
keyword_articles = pd.DataFrame(article["keywords"])
keyword_articles
# Out:
# Empty DataFrame
# Columns: []
# Index: []
