# %%
import requests
import pandas as pd
from pprint import pprint
from config import api_key
import time
import json

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
query = "movies"

begin_date = "20170328"
end_date = "20170526"

# %%
articles_list = []

for page in range(0, 10):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    time.sleep(1)
    
    for article in articles["response"]["docs"]:
        articles_list.append(article)

# %%
pprint(article)
# Out:
# {'_id': 'nyt://article/6f892c7e-a7f3-5bfd-8c52-0273370f4281',
#  'abstract': 'Debra Winger and Tracy Letts play a couple whose passions for '
#              'each other have reignited, to the chagrin of their lovers.',
#  'byline': {'organization': None,
#             'original': 'By Jeannette Catsoulis',
#             'person': [{'firstname': 'Jeannette',
#                         'lastname': 'Catsoulis',
#                         'middlename': None,
#                         'organization': '',
#                         'qualifier': None,
#                         'rank': 1,
#                         'role': 'reported',
#                         'title': None}]},
#  'document_type': 'article',
#  'headline': {'content_kicker': None,
#               'kicker': None,
#               'main': 'Review: Can Cheating Save a Marriage? Ask ‘The Lovers’',
#               'name': None,
#               'print_headline': 'The Lovers',
#               'seo': None,
#               'sub': None},
#  'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Movies'},
#               {'major': 'N',
#                'name': 'creative_works',
#                'rank': 2,
#                'value': 'The Lovers (Movie)'},
#               {'major': 'N',
#                'name': 'persons',
#                'rank': 3,
#                'value': 'Letts, Tracy'},
#               {'major': 'N',
#                'name': 'persons',
#                'rank': 4,
#                'value': 'Winger, Debra'},
#               {'major': 'N',
#                'name': 'persons',
#                'rank': 5,
#                'value': 'Jacobs, Azazel'}],
#  'lead_paragraph': 'If all middle-aged marrieds were having as much sex as '
#                    'Mary and Michael (Debra Winger and Tracy Letts) in “The '
#                    'Lovers,” then the ratings for “NCIS” would go into a '
#                    'tailspin. Yet the extracurricular bonking that they '
#                    'gingerly enjoy — she with a needy writer (Aidan Gillen) '
#                    'and he with a neurotic ballet dancer (Melora Walters) — '
#                    'appears to bring only marginally more pleasure than their '
#                    'sclerotic union.',
#  'multimedia': [{'caption': None,
#                  'credit': None,
#                  'crop_name': 'watch308',
#                  'height': 348,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'watch308',
#                  'subtype': 'watch308',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-watch308.jpg',
#                  'width': 312},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'watch268',
#                  'height': 303,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'watch268',
#                  'subtype': 'watch268',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-watch268.jpg',
#                  'width': 272},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'sfSpan',
#                  'height': 263,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'sfSpan',
#                  'subtype': 'sfSpan',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-sfSpan.jpg',
#                  'width': 395},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeHorizontalJumbo',
#                  'height': 682,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeHorizontalJumbo',
#                  'subtype': 'largeHorizontalJumbo',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-largeHorizontalJumbo.jpg',
#                  'width': 1024},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeHorizontal375',
#                  'height': 250,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeHorizontal375',
#                  'subtype': 'largeHorizontal375',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-largeHorizontal375.jpg',
#                  'width': 375},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'articleLarge',
#                  'height': 298,
#                  'legacy': {'xlarge': 'images/2017/05/05/arts/05LOVERS/05LOVERS-articleLarge.jpg',
#                             'xlargeheight': 298,
#                             'xlargewidth': 600},
#                  'rank': 0,
#                  'subType': 'xlarge',
#                  'subtype': 'xlarge',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-articleLarge.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog480',
#                  'height': 238,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog480',
#                  'subtype': 'blog480',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-blog480.jpg',
#                  'width': 480},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog427',
#                  'height': 212,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog427',
#                  'subtype': 'blog427',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-blog427.jpg',
#                  'width': 427},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'tmagArticle',
#                  'height': 294,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'tmagArticle',
#                  'subtype': 'tmagArticle',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-tmagArticle.jpg',
#                  'width': 592},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'jumbo',
#                  'height': 509,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'jumbo',
#                  'subtype': 'jumbo',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-jumbo.jpg',
#                  'width': 1024},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog225',
#                  'height': 112,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog225',
#                  'subtype': 'blog225',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-blog225.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master675',
#                  'height': 335,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master675',
#                  'subtype': 'master675',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-master675.jpg',
#                  'width': 675},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master180',
#                  'height': 89,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master180',
#                  'subtype': 'master180',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-master180.jpg',
#                  'width': 180},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master768',
#                  'height': 382,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master768',
#                  'subtype': 'master768',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-master768.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'popup',
#                  'height': 323,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'popup',
#                  'subtype': 'popup',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-popup.jpg',
#                  'width': 650},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog533',
#                  'height': 265,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog533',
#                  'subtype': 'blog533',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-blog533.jpg',
#                  'width': 533},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'tmagSF',
#                  'height': 180,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'tmagSF',
#                  'subtype': 'tmagSF',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-tmagSF.jpg',
#                  'width': 362},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'slide',
#                  'height': 298,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'slide',
#                  'subtype': 'slide',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-slide.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'superJumbo',
#                  'height': 1017,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'superJumbo',
#                  'subtype': 'superJumbo',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-superJumbo.jpg',
#                  'width': 2048},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master1050',
#                  'height': 522,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master1050',
#                  'subtype': 'master1050',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-master1050.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master495',
#                  'height': 246,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master495',
#                  'subtype': 'master495',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-master495.jpg',
#                  'width': 495},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master315',
#                  'height': 156,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master315',
#                  'subtype': 'master315',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-master315.jpg',
#                  'width': 315},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbWide',
#                  'height': 126,
#                  'legacy': {'wide': 'images/2017/05/05/arts/05LOVERS/05LOVERS-thumbWide.jpg',
#                             'wideheight': 126,
#                             'widewidth': 190},
#                  'rank': 0,
#                  'subType': 'wide',
#                  'subtype': 'wide',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-thumbWide.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoThumb',
#                  'height': 50,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoThumb',
#                  'subtype': 'videoThumb',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoThumb.jpg',
#                  'width': 75},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoLarge',
#                  'height': 507,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoLarge',
#                  'subtype': 'videoLarge',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoLarge.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo210',
#                  'height': 140,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo210',
#                  'subtype': 'mediumThreeByTwo210',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-mediumThreeByTwo210.jpg',
#                  'width': 210},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo225',
#                  'height': 150,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo225',
#                  'subtype': 'mediumThreeByTwo225',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-mediumThreeByTwo225.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo440',
#                  'height': 293,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo440',
#                  'subtype': 'mediumThreeByTwo440',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-mediumThreeByTwo440.jpg',
#                  'width': 440},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo252',
#                  'height': 168,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo252',
#                  'subtype': 'mediumThreeByTwo252',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-mediumThreeByTwo252.jpg',
#                  'width': 252},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo378',
#                  'height': 252,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo378',
#                  'subtype': 'mediumThreeByTwo378',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-mediumThreeByTwo378.jpg',
#                  'width': 378},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'hpLarge',
#                  'height': 287,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'hpLarge',
#                  'subtype': 'hpLarge',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-hpLarge.jpg',
#                  'width': 511},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeWidescreen573',
#                  'height': 322,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeWidescreen573',
#                  'subtype': 'largeWidescreen573',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-largeWidescreen573.jpg',
#                  'width': 573},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeWidescreen1050',
#                  'height': 590,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeWidescreen1050',
#                  'subtype': 'largeWidescreen1050',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-largeWidescreen1050.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'verticalTwoByThree735',
#                  'height': 1103,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'verticalTwoByThree735',
#                  'subtype': 'verticalTwoByThree735',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-verticalTwoByThree735.jpg',
#                  'width': 735},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'facebookJumbo',
#                  'height': 549,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'facebookJumbo',
#                  'subtype': 'facebookJumbo',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-facebookJumbo.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSmall',
#                  'height': 281,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSmall',
#                  'subtype': 'videoSmall',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSmall.jpg',
#                  'width': 500},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoHpMedium',
#                  'height': 211,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoHpMedium',
#                  'subtype': 'videoHpMedium',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoHpMedium.jpg',
#                  'width': 375},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine600',
#                  'height': 338,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine600',
#                  'subtype': 'videoSixteenByNine600',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine600.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine540',
#                  'height': 304,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine540',
#                  'subtype': 'videoSixteenByNine540',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine540.jpg',
#                  'width': 540},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine495',
#                  'height': 278,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine495',
#                  'subtype': 'videoSixteenByNine495',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine495.jpg',
#                  'width': 495},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine390',
#                  'height': 219,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine390',
#                  'subtype': 'videoSixteenByNine390',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine390.jpg',
#                  'width': 390},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine480',
#                  'height': 270,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine480',
#                  'subtype': 'videoSixteenByNine480',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine480.jpg',
#                  'width': 480},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine310',
#                  'height': 174,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine310',
#                  'subtype': 'videoSixteenByNine310',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine310.jpg',
#                  'width': 310},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine225',
#                  'height': 126,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine225',
#                  'subtype': 'videoSixteenByNine225',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine225.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine96',
#                  'height': 54,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine96',
#                  'subtype': 'videoSixteenByNine96',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine96.jpg',
#                  'width': 96},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine768',
#                  'height': 432,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine768',
#                  'subtype': 'videoSixteenByNine768',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine768.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine150',
#                  'height': 84,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine150',
#                  'subtype': 'videoSixteenByNine150',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine150.jpg',
#                  'width': 150},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine1050',
#                  'height': 591,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine1050',
#                  'subtype': 'videoSixteenByNine1050',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNine1050.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNineJumbo1600',
#                  'height': 899,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNineJumbo1600',
#                  'subtype': 'videoSixteenByNineJumbo1600',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoSixteenByNineJumbo1600.jpg',
#                  'width': 1600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'articleInline',
#                  'height': 94,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'articleInline',
#                  'subtype': 'articleInline',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-articleInline.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'hpSmall',
#                  'height': 81,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'hpSmall',
#                  'subtype': 'hpSmall',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-hpSmall.jpg',
#                  'width': 163},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blogSmallInline',
#                  'height': 75,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blogSmallInline',
#                  'subtype': 'blogSmallInline',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-blogSmallInline.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumFlexible177',
#                  'height': 88,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumFlexible177',
#                  'subtype': 'mediumFlexible177',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-mediumFlexible177.jpg',
#                  'width': 177},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'square320',
#                  'height': 320,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'square320',
#                  'subtype': 'square320',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-square320.jpg',
#                  'width': 320},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'filmstrip',
#                  'height': 190,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'filmstrip',
#                  'subtype': 'filmstrip',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-filmstrip.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'square640',
#                  'height': 640,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'square640',
#                  'subtype': 'square640',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-square640.jpg',
#                  'width': 640},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'moth',
#                  'height': 151,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'moth',
#                  'subtype': 'moth',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-moth.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumSquare149',
#                  'height': 149,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumSquare149',
#                  'subtype': 'mediumSquare149',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-mediumSquare149.jpg',
#                  'width': 149},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbStandard',
#                  'height': 75,
#                  'legacy': {'thumbnail': 'images/2017/05/05/arts/05LOVERS/05LOVERS-thumbStandard.jpg',
#                             'thumbnailheight': 75,
#                             'thumbnailwidth': 75},
#                  'rank': 0,
#                  'subType': 'thumbnail',
#                  'subtype': 'thumbnail',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-thumbStandard.jpg',
#                  'width': 75},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbLarge',
#                  'height': 150,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'thumbLarge',
#                  'subtype': 'thumbLarge',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-thumbLarge.jpg',
#                  'width': 150},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'smallSquare252',
#                  'height': 252,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'smallSquare252',
#                  'subtype': 'smallSquare252',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-smallSquare252.jpg',
#                  'width': 252},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blogSmallThumb',
#                  'height': 50,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blogSmallThumb',
#                  'subtype': 'blogSmallThumb',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-blogSmallThumb.jpg',
#                  'width': 50},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'smallSquare168',
#                  'height': 168,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'smallSquare168',
#                  'subtype': 'smallSquare168',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-smallSquare168.jpg',
#                  'width': 168},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoFifteenBySeven1305',
#                  'height': 609,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoFifteenBySeven1305',
#                  'subtype': 'videoFifteenBySeven1305',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoFifteenBySeven1305.jpg',
#                  'width': 1305},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoFifteenBySeven2610',
#                  'height': 1218,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoFifteenBySeven2610',
#                  'subtype': 'videoFifteenBySeven2610',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-videoFifteenBySeven2610.jpg',
#                  'width': 2610},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'miniMoth',
#                  'height': 70,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'miniMoth',
#                  'subtype': 'miniMoth',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-miniMoth.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'windowsTile336H',
#                  'height': 336,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'windowsTile336H',
#                  'subtype': 'windowsTile336H',
#                  'type': 'image',
#                  'url': 'images/2017/05/05/arts/05LOVERS/05LOVERS-windowsTile336H.jpg',
#                  'width': 694}],
#  'news_desk': 'Weekend',
#  'print_page': '6',
#  'print_section': 'C',
#  'pub_date': '2017-05-04T14:59:02+0000',
#  'section_name': 'Movies',
#  'snippet': 'Debra Winger and Tracy Letts play a couple whose passions for '
#             'each other have reignited, to the chagrin of their lovers.',
#  'source': 'The New York Times',
#  'type_of_material': 'Review',
#  'uri': 'nyt://article/6f892c7e-a7f3-5bfd-8c52-0273370f4281',
#  'web_url': 'https://www.nytimes.com/2017/05/04/movies/the-lovers-review.html',
#  'word_count': 299}

# %%
for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]} ')
    print('---------------------------')
# Out:
# A snippet from the article: He wasn’t the best Bond. But he wasn’t the worst.
# ---------------------------
# A snippet from the article: Complex special effects can mean several thousand crew members are listed at the end. But not all workers are there, and some wish the scrolls were even longer.
# ---------------------------
# A snippet from the article: A retrospective features 31 works by this director, stretching from the silent era into the 1940s.
# ---------------------------
# A snippet from the article: Our guide to film series and special screenings.
# ---------------------------
# A snippet from the article: The new summer season isn’t exactly a monster mash, but a clutch of new creature features has our critics wondering what scares us now and why.
# ---------------------------
# A snippet from the article: A follow-up to the classic 1986 movie is in the works.
# ---------------------------
# A snippet from the article: On the 40th anniversary of the original film's release, we take a look at how The New York Times covered the movie, and how audiences embraced it.
# ---------------------------
# A snippet from the article: This film version of Camus’s novel, starring the Italian movie idol, will be screened twice as part of a retrospective of its star’s career.
# ---------------------------
# A snippet from the article: The latest in the “Pirates of the Caribbean” franchise brings back Johnny Depp’s Captain Sparrow but leaves the joy an ocean away.
# ---------------------------
# A snippet from the article: The director said he was stepping back “to be with my family, be with my kids, who really need me.” Joss Whedon will take over for Mr. Snyder.
# ---------------------------
# A snippet from the article: Teresa Palmer has a breakthrough role as a young woman on holiday in Berlin whose instant romance with a stranger results in her abduction.
# ---------------------------
# A snippet from the article: David Michôd’s film, adapted from a Michael Hastings book, puts a leader with boundless ignorance in a volatile country.
# ---------------------------
# A snippet from the article: Matías Piñeiro’s follows the trials, tribulations and romances inspired by two of the playwright’s heroines from “A Midsummer Night’s Dream.”
# ---------------------------
# A snippet from the article: Jason Bourque’s thriller examines the moral compromises of meting out death from afar, and the unraveling of a home when a victim comes to supper.
# ---------------------------
# A snippet from the article: The Cannes veteran talks about movies, sexism, female rage and “The Beguiled,” the third film that she’s made with the director Sofia Coppola.
# ---------------------------
# A snippet from the article: If you brush up on these five films, you’ll have a jump-start on the season in multiplexes.
# ---------------------------
# A snippet from the article: The power and resourcefulness of women are on display in this small-scale comedy, which manages to speak to a broader political movement.
# ---------------------------
# A snippet from the article: On its anniversary, the gritty John Travolta disco classic gets a director’s cut, with 15 extra minutes.
# ---------------------------
# A snippet from the article: Dwayne Johnson and his lifeguard squad try to save the Bay while providing the sort of sleazy, wholesome entertainment this ’90s series was known for.
# ---------------------------
# A snippet from the article: Mr. Hardy has signed on to lead “Venom,” a 2018 Marvel movie connected to “Spider-Man: Homecoming.”
# ---------------------------
# A snippet from the article: “Guardians of the Galaxy Vol. 2” came in second, while the teenage drama “Everything, Everything” was a respectable third.
# ---------------------------
# A snippet from the article: Among the movies in competition, disappointments abound, and our critic is left scratching her head about why some titles were included.
# ---------------------------
# A snippet from the article: Gen. Stanley A. McChrystal is the commander alluded to in David Michôd’s satirical portrait of a man in over his head and enthralled by his own hype.
# ---------------------------
# A snippet from the article: With DVDs fast becoming relics and box-office numbers stagnating, movie studios are looking to toys and other licensed products to raise revenue.
# ---------------------------
# A snippet from the article: Ms. Merrill’s upper-class roles often reflected her own privileged background.
# ---------------------------
# A snippet from the article: He talks about portraying historical figures like Einstein and his fresh turn as Barbossa in “Pirates of the Caribbean: Dead Men Tell No Tales.”
# ---------------------------
# A snippet from the article: Mr. Moore was 45 when he inherited the role and had the longest run with it.
# ---------------------------
# A snippet from the article: The lake where Johnny lifted Baby may be gone, but the North Carolina and Virginia sites where the film was shot still offer plenty of nostalgia.
# ---------------------------
# A snippet from the article: The Museum of the Moving Image in Queens will feature 12 films from the versatile actor James Caan.
# ---------------------------
# A snippet from the article: Baby boomers keep reminding us about Sean Connery, but enough already. And millennials, you just need to listen to us.
# ---------------------------
# A snippet from the article: Organizers held a moment of silence and canceled fireworks after the bombing in Manchester, England. But in other respects, the festival is carrying on as before.
# ---------------------------
# A snippet from the article: In this adaptation of Janet Fitch’s novel, two women react very differently to a suicide.
# ---------------------------
# A snippet from the article: The company’s chief content officer, Ted Sarandos, says the festival knew full well that its competition titles might not get a theatrical release.
# ---------------------------
# A snippet from the article: In Peru, a woman confronts her illness and fears with help from medicinal plants.
# ---------------------------
# A snippet from the article: Amandla Stenberg plays a teenager with an immune system disorder who falls for the boy next door, and risks everything.
# ---------------------------
# A snippet from the article: The stars turned out for Vanity Fair’s annual A-list gathering during the film festival.
# ---------------------------
# A snippet from the article: Trine Dyrholm is “magnificent” as a woman buckling under the strain of her career and her marriage in Thomas Vinterberg’s latest film.
# ---------------------------
# A snippet from the article: Our guide to film series and special screenings.
# ---------------------------
# A snippet from the article: From the modern Philippines, Lav Diaz’s haunting and pessimistic take on a Tolstoy story.
# ---------------------------
# A snippet from the article: Known for the film complex at Lincoln Center that bears her name, Ms. Munroe was an Emmy-winning graphic designer whose movie work included “The Producers.”
# ---------------------------
# A snippet from the article: Stephen Fingleton wrote and directed this impressively lean story, centering on a man coping amid the fallout of an unexplained catastrophe.
# ---------------------------
# A snippet from the article: The filmmaker had resisted calls for a sequel but was intrigued by the idea of doing a short for charity. Bill Nighy, Liam Neeson and others signed on.
# ---------------------------
# A snippet from the article: This passionate political movie tells the story of Wladyslaw Strzeminski, a real-life artist who suffered under Soviet rule.
# ---------------------------
# A snippet from the article: Greg and his brothers are dragged on a dreary road trip by their parents. You can probably guess the rest.
# ---------------------------
# A snippet from the article: The new entry in Ridley Scott’s long-lived franchise is committed to the canny management of expectations, but that doesn’t diminish its creepiness.
# ---------------------------
# A snippet from the article: A man indulges a fantasy to escape his routine by camping out in a storage room above his garage and observing his own absence.
# ---------------------------
# A snippet from the article: Sometimes the jeering means the movie is provocative. Sometimes it’s a comment on the festival’s decisions. And sometimes the picture is plain awful.
# ---------------------------
# A snippet from the article: A report looking at Sundance, Telluride and other festivals discovered that programmers chose features by men three times as often as those by women.
# ---------------------------
# A snippet from the article: The streaming giant Netflix doesn’t see theaters as essential, but in France even TV channels have a vested interest in theatrical releases. It’s uniquely French.
# ---------------------------
# A snippet from the article: Mr. Grey, who played a pivotal role in the creation of television hits like “The Sopranos,” helped blend the art of talent management with TV and film production.
# ---------------------------
# A snippet from the article: He’ll be the first M.C. since the ’90s to lead the ceremony two years in a row. Also returning will be the producers of the last telecast.
# ---------------------------
# A snippet from the article: Warner Bros. gambled $300 million on “King Arthur: Legend of the Sword,” which bombed with $14.7 million in initial ticket sales.
# ---------------------------
# A snippet from the article: Our guide to film series and special screenings.
# ---------------------------
# A snippet from the article: Guy Ritchie narrates a sequence from "King Arthur: Legend of the Sword," featuring Charlie Hunnam and Jude Law.
# ---------------------------
# A snippet from the article: Alex Karpovsky of “Girls” stars as a bad comic opening for a good folk-rocker. As their trip rolls along, tensions bubble up.
# ---------------------------
# A snippet from the article: This feature debut of the Australian filmmaker Ben Young resembles a real-life couple’s killing spree in the 1980s.
# ---------------------------
# A snippet from the article: The film “Get Out” is the latest horror blockbuster in an eight-year run of lean, inventive films from the Hollywood producer.
# ---------------------------
# A snippet from the article: “Léon Morin, Priest,” an erotically charged tale of occupied France by Jean-Pierre Melville, is revived in a new digital restoration.
# ---------------------------
# A snippet from the article: As a reliable purveyor of Looney Tunes, Boomerang has appeal for families; Crunchyroll’s offerings run from anime to current Japanese television shows.
# ---------------------------
# A snippet from the article: For an adaptation of a novel about domestic strife, “The Dinner,” why not a guy who grew up reading about movies, not watching them? Meet Oren Moverman.
# ---------------------------
# A snippet from the article: Working with a minimalist script and a tight budget, the director Doug Liman brings vein-popping intensity to a claustrophobic standoff in Iraq.
# ---------------------------
# A snippet from the article: The Arthurian legend gets a makeover with quips, winks, body blows, digital elephants and an easy, breezy Charlie Hunnam.
# ---------------------------
# A snippet from the article: Alexi Pappas, a runner who, in real life, competed at the 2016 Olympics, helped write, direct and produce — and stars in — a film about a runner.
# ---------------------------
# A snippet from the article: The islanders are still driven to lawlessness after their whisky runs out, but this remake lacks the luster of the original.
# ---------------------------
# A snippet from the article: Rama Burshtein received acclaim for her debut feature, “Fill the Void.” Now she’s back with another biting, multilayered romantic comedy.
# ---------------------------
# A snippet from the article: Cheryl Boone Isaacs, who has served 24 years on the board, has told friends that the academy’s serial controversies have exhausted her.
# ---------------------------
# A snippet from the article: The director discusses a sequence from “King Arthur: Legend of the Sword,” featuring Charlie Hunnam and Jude Law.
# ---------------------------
# A snippet from the article: Maria Schrader’s film looks at this Austrian man of letters who fell into despair while living in the Americas.
# ---------------------------
# A snippet from the article: A social worker tries to connect with a troubled 17-year-old through music, but the girl’s street-tough best friend stands in the way.
# ---------------------------
# A snippet from the article: A father is immersed in the lowrider world, while a son wants only to pursue his art. And then another son is released from prison.
# ---------------------------
# A snippet from the article: In this film, Diane Lane stars as a Hollywood producer’s wife whose road trip to Paris becomes a journey of self-discovery — and a gastronomic affair.
# ---------------------------
# A snippet from the article: Perhaps you’ve forgotten what goes into an essential swashbuckler. Let “The Adventures of Robin Hood” (1938), with Errol Flynn, remind you.
# ---------------------------
# A snippet from the article: Amy Schumer teams up with Goldie Hawn in “Snatched.” Only one of them gets to be funny.
# ---------------------------
# A snippet from the article: After an uproar by French cinema owners unhappy that Netflix will not show its films in theaters, the festival moves to change its rules.
# ---------------------------
# A snippet from the article: Julian Rosefeldt’s art installation is now a film, with this chameleonic actress morphing into multiple characters.
# ---------------------------
# A snippet from the article: Mr. Hunnam, who carefully considers his acting roles, forced a meeting with the director Guy Ritchie for his film “King Arthur.”
# ---------------------------
# A snippet from the article: Bette Gordon’s thriller, starring Josh Charles and Julia Stiles, is notable for its depth of psychological observation.
# ---------------------------
# A snippet from the article: Pirates, aliens and lifeguards come to the big screen this month.
# ---------------------------
# A snippet from the article: The “Blade Runner 2049” trailer shows more than it tells — but what a beautiful show.
# ---------------------------
# A snippet from the article: Critics review “The Circle,” “Casting JonBenet” and “Obit" for The New York Times.
# ---------------------------
# A snippet from the article: The sequel’s $145 million in domestic ticket sales on its opening weekend dwarfed the original’s, but turnout fell slightly short of expectations.
# ---------------------------
# A snippet from the article: Millie Bobby Brown, the 13-year-old star of “Stranger Things,” won the gender-neutral acting award for a television series.
# ---------------------------
# A snippet from the article: Mr. Gordon starred on television and in film for decades, often playing tough-guy roles.
# ---------------------------
# A snippet from the article: Hollywood often cites box office results to explain the lack of diversity on screen, but take a closer look. The numbers argue in favor of diversity.
# ---------------------------
# A snippet from the article: The Israeli actress appeared in “Lord Jim,” the 1967 “Casino Royale” and other movies before a career as a singer and actress in Germany.
# ---------------------------
# A snippet from the article: The 61-year-old actress stars in “The Lovers,” a dour romantic comedy about marriage and affairs.
# ---------------------------
# A snippet from the article: Charlize Theron, Michelle Rodriguez and other actresses are giving careful thought to their new roles as they change what it means to be an action star.
# ---------------------------
# A snippet from the article: The performers who won the roles of Tupac Shakur, the new Spider-Man and other parts share the stories behind their successful auditions.
# ---------------------------
# A snippet from the article: Whatever your taste — comedies, documentaries, historical dramas, effects spectaculars — movie theaters have something to offer you this season.
# ---------------------------
# A snippet from the article: Elle Fanning plays an adolescent changing from female to male in this earnest but overstuffed movie, which piles on the complications as Ramona becomes Ray.
# ---------------------------
# A snippet from the article: Ridley Scott’s film “Alien” gave audiences one of the scariest space monsters in movie history. Here’s a look at how the 1979 film has influenced the genre.
# ---------------------------
# A snippet from the article: Richard Gere and Steve Coogan face off as estranged brothers with serious family matters to attend to in this film adaptation of Herman Koch’s book.
# ---------------------------
# A snippet from the article: This Italian comedy-drama tells an interesting, if not tasteful, story about polar opposites bonding in a mental institution.
# ---------------------------
# A snippet from the article: In this ultra-low-budget ghost story, the living may exhibit more unsettling behavior than the dead.
# ---------------------------
# A snippet from the article: Chris Pratt, Zoe Saldana and the crew are back for this sequel to the 2014 hit about a ragtag group of futuristic fighters.
# ---------------------------
# A snippet from the article: Our guide to film series and special screenings.
# ---------------------------
# A snippet from the article: The director discusses a sequence from the film that was inspired by Alfred Hitchcock's “North by Northwest.”
# ---------------------------
# A snippet from the article: The 1979 sci-fi horror film has left its mark on many films, from a “Friday the 13th” sequel to the newest “Alien” prequel.
# ---------------------------
# A snippet from the article: Stéphane Brizé’s ravishing adaptation of a Guy de Maupassant novel traces the fluctuating fortunes of a woman in 19th-century France.
# ---------------------------
# A snippet from the article: Debra Winger and Tracy Letts play a couple whose passions for each other have reignited, to the chagrin of their lovers.
# ---------------------------

# %%
# for article in articles_list:
#     pprint(f'keywords from the article: {article["keywords"]} ')
#     print('---------------------------')

# %%
# for article in articles_list:
#     print(f'Publication date from the article: {article["pub_date"]} ')
#     print('---------------------------')

# %%
# for article in articles_list:
#     pprint(f'Categorized as news from: {article["section_name"]} ')
#     print('---------------------------')

# %%
# article["keywords"][0]

# %%
keyword_articles = pd.DataFrame(article["keywords"])
keyword_articles
# Out:
#              name               value  rank major
# 0         subject              Movies     1     N
# 1  creative_works  The Lovers (Movie)     2     N
# 2         persons        Letts, Tracy     3     N
# 3         persons       Winger, Debra     4     N
# 4         persons      Jacobs, Azazel     5     N
