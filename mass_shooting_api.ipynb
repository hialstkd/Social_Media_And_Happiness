# %%
import requests
from pprint import pprint
from config import api_key
import time

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
query = "mass shooting"

begin_date = "20170328"
end_date = "20170526"

# %%
articles_list = []

for page in range(0, 10):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    time.sleep(1)
    
    for article in articles["response"]["docs"]:
        articles_list.append(article)

# %%
for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]}')
    print('---------------------------')
# Out:
# A snippet from the article: The narrator of Courtney Baron’s play reacts with horror when she learns an ex-boyfriend is responsible for a mass shooting.
# ---------------------------
# A snippet from the article: One person was killed and at least six wounded before the police shot and killed the attacker, who was “distraught” after a breakup, the authorities said.
# ---------------------------
# A snippet from the article: We are honoring each of the Top 10 winners of our Fourth Annual Student Editorial Contest by publishing an essay a day. Here, an essay by Daina Kalnina, age 15.
# ---------------------------
# A snippet from the article: High winds have grounded a huge iceberg on the Newfoundland shore, to the delight of camera-wielding sightseers.
# ---------------------------
# A snippet from the article: Officials are seeking the reason for an “unusual mortality event” that has left 41 humpback whales dead since early 2016 from North Carolina to Maine.
# ---------------------------
# A snippet from the article: This word has appeared in 102 articles on nytimes.com in the past year.
# ---------------------------
# A snippet from the article: President Trump continues his bonhomie with the president of the Philippines, who is overseeing a campaign of mass murder.
# ---------------------------
# A snippet from the article: The vision of the good guy gunning down the bad guy is driving the modern gun rights debate.
# ---------------------------
# A snippet from the article: Hundreds of defenseless women are shot to death each year by current or former partners.
# ---------------------------
# A snippet from the article: The idea that the police have retreated under siege will not go away. But even if it's true, is it necessarily bad?
# ---------------------------
# A snippet from the article: Monday: A looming writers’ strike, a mass shooting in San Diego, and an obituary for an accordionist heartthrob from Fresno.
# ---------------------------
# A snippet from the article: Scientists recorded a rare physical fight between two male cuttlefish.
# ---------------------------
# A snippet from the article: The complaint, which accuses the president of mass murder, was declared insufficient by the Justice Committee of the House of Representatives, which is controlled by Duterte backers.
# ---------------------------
# A snippet from the article: Hannah Tinti’s new novel, “The Twelve Lives of Samuel Hawley,” centers on the close relationship between a girl and her outlaw father.
# ---------------------------
# A snippet from the article: Mr. Palermo was shot in 1991 while defending two waitresses from an attack outside a Dallas restaurant. He lived in chronic pain but had no regrets.
# ---------------------------
# A snippet from the article: How the face of the brand became the symbol of its fall.
# ---------------------------
# A snippet from the article: The former tight end with the New England Patriots, who was convicted of first-degree murder in 2015, was found in his cell on Wednesday morning.
# ---------------------------
# A snippet from the article: Here’s what you need to know at the end of the day.
# ---------------------------
# A snippet from the article: A close associate of the Philippines president gave the government’s first defense of its human rights record before an international body.
# ---------------------------
# A snippet from the article: Here’s what you need to know at the end of the day.
# ---------------------------
# A snippet from the article: Here’s what you need to know at the end of the day.
# ---------------------------
# A snippet from the article: India resorts to brute force to crush Kashmir protests.
# ---------------------------
# A snippet from the article: The Facebook chief plans to visit every state in the union and learn more about a sliver of the nearly two billion people who use the social network regularly.
# ---------------------------
# A snippet from the article: Here’s what you need to know to start your day.
# ---------------------------
# A snippet from the article: Here’s what you need to know at the end of the day.
# ---------------------------
# A snippet from the article: Here’s what you need to know at the end of the day.
# ---------------------------
# A snippet from the article: It seemed like the beginning of a good relationship. It ended in a murder trial and a suicide.
# ---------------------------
# A snippet from the article: Most complaints against imitations depend on a hard nature-versus-art distinction, one that never really holds up.
# ---------------------------
# A snippet from the article: Hernandez was once the youngest player in the N.F.L. and a star for its best team. But he remained tangled in his roots.
# ---------------------------
# A snippet from the article: The California event that defined the spirit of the Summer of Love, and gave Jimi Hendrix and Janis Joplin a boost, will rise again in June at 50.
# ---------------------------
# A snippet from the article: In remote Nigerian forests, members of a century-old group are using hunting skills honed over generations to join the fight against the Islamist militants.
# ---------------------------
# A snippet from the article: We must understand and honor the past in order to learn from and not repeat it.
# ---------------------------
# A snippet from the article: The family of Seth Rich objected after the network promoted a theory that Mr. Rich was killed because he shared D.N.C. emails with WikiLeaks.
# ---------------------------
# A snippet from the article: If it weren’t for Sy and Nikki, the Stussy brothers might have made nice by now. But this is “Fargo,” and the body count is still low.
# ---------------------------
# A snippet from the article: Critics of “The Ottoman Lieutenant” say it was aimed at undercutting another film, “The Promise,” by falsely painting the Armenian genocide as two-sided.
# ---------------------------
# A snippet from the article: Did The Times fail to give due credit to an artist in its profile of another’s work? And should the paper have memorialized an actress? Plus some questions on word choice.
# ---------------------------
# A snippet from the article: A human rights lawsuit over a 2008 attack in Haiti, a mysterious death and a decade-old killing cast a light on the government’s culture of impunity.
# ---------------------------
# A snippet from the article: The documentarian is one of the greatest directors working today. A complete career retrospective opens in New York April 14.
# ---------------------------
# A snippet from the article: Like virtually everything else in the Trump era, poetry has gotten sharply political these days.
# ---------------------------
# A snippet from the article: The president has often bemoaned Chicago’s rising street violence. But residents say his long, tangled relationship with the city explains a lot.
# ---------------------------
# A snippet from the article: The 74-year-old force behind the avant-garde label Comme des Garçons makes otherworldly clothes that express hidden desires and fears.
# ---------------------------
# A snippet from the article: Americans may be losing faith in the idea that any figure or institution can rise entirely above the partisan fray.
# ---------------------------
# A snippet from the article: With a legal fight unfolding over a series of scheduled executions, Mr. Echols makes a rare trip back to the state where he spent 18 years on death row.
# ---------------------------
# A snippet from the article: The shooting in an elementary school was an apparent murder-suicide.
# ---------------------------
# A snippet from the article: Two women, both injured in the Boston Marathon bombing, find self-understanding and love, while a third takes up running to reshape her body and her life.
# ---------------------------
# A snippet from the article: Why Burmese pythons may be the best way to study diabetes, heart disease and the protective effects of gastric-bypass surgery in humans.
# ---------------------------
# A snippet from the article: Using classic K.G.B. tactics, security officers lured gay men into traps and tortured them into giving up the identities of others like them.
# ---------------------------
# A snippet from the article: Our roundup of the news and feature stories about young people that have recently appeared across sections of NYTimes.com.
# ---------------------------
# A snippet from the article: A historian of conservatism looks back at how he and his peers failed to anticipate the rise of the president.
# ---------------------------
# A snippet from the article: Federal prosecutors said the three men robbed the former Knicks forward of cellphones, jewelry and gold teeth in an orchestrated attack after he exited a strip club, leaving him shot in the knee.
# ---------------------------
# A snippet from the article: The comeback of distressed and lost communities is the story of Bill Clinton’s America, not Donald Trump’s.
# ---------------------------
# A snippet from the article: The billionaire investors discussed free trade and their working relationship during an interview at the Brazil Conference in Cambridge, Mass.
# ---------------------------
# A snippet from the article: The former Islamist has started a foundation to combat extremism among Muslims — and has made a lot of enemies in the process.
# ---------------------------
# A snippet from the article: Cricket’s rapid rise in Afghanistan has produced a devoted fan base and players who are taking their place among the sport’s best.
# ---------------------------
# A snippet from the article: An installation piece with overlapping performances of works for solo violin at the Cathedral Church of St. John the Divine followed a symposium in Amherst, Mass.
# ---------------------------
# A snippet from the article: There will never be another Arnold Palmer. But many of his endearing qualities can be found in the men competing at the Masters. Together they form golf’s composite King.
# ---------------------------
# A snippet from the article: Berns is not as well known as Phil Spector, but this songwriter and music producer amassed an impressive number of durable pop and R&B hits in the 1960s.
# ---------------------------
# A snippet from the article: Discos Barba Azul, which operated until 2013, nurtured a massive cross-border underground. A new compilation collects and celebrates its recordings.
# ---------------------------
# A snippet from the article: The French group’s sixth album, “Ti Amo,” is another volley of shimmery disco rock, with a hint of the darkness that has rattled Paris.
# ---------------------------
# A snippet from the article: The police said that DNA collected from Vanessa Marcotte’s hands helped lead to an arrest in her death.
# ---------------------------
# A snippet from the article: Ideas for helping even the most verse averse find something to enjoy.
# ---------------------------
# A snippet from the article: Members of Congress facing furious crowds could learn a lesson from social science and start treating protesters as individuals.
# ---------------------------
# A snippet from the article: The conductor Leon Botstein champions a little-known Elgar oratorio in a stirring performance with the American Symphony Orchestra at Carnegie Hall.
# ---------------------------
# A snippet from the article: Young adults who decide to abandon their cloistered Jewish communities have only one another — and a single organization — to help them navigate the alternate reality of modern-day New York.
# ---------------------------
# A snippet from the article: Early on, that area was seen as an ideal spot for (theoretically) final resting places.
# ---------------------------
# A snippet from the article: The avant-garde vocalist looks back at her nearly 40-year career as she releases two new albums.
# ---------------------------
# A snippet from the article: S. Jonathan Bass’s “He Calls Me by Lightning” examines the conviction of a black youth in the 1957 killing of a policeman, and the 44-year legal saga that followed.
# ---------------------------
# A snippet from the article: Diane Roseman makes her New York Times Crossword debut — assisted by her son, the constructor Zachary Spitz.
# ---------------------------
# A snippet from the article: Native American tribes are waiting for the return of their sacred items from the collection of a Massachusetts seminary.
# ---------------------------
# A snippet from the article: Six new paperbacks to check out this week.
# ---------------------------
# A snippet from the article: Six new paperbacks to check out this week.
# ---------------------------
# A snippet from the article: Paul Mihailidis, director of a new graduate program on civic media at Emerson College, answers questions about news literacy.
# ---------------------------
# A snippet from the article: We created a set of charts for several metropolitan areas that look at school quality, home price and commute. There are deals to be had.
# ---------------------------
# A snippet from the article: The problem (and future) of clothes sizing.
# ---------------------------
# A snippet from the article: Protesters gathered in Caracas to accuse President Nicolás Maduro of trying to eviscerate Venezuela’s democratic institutions and establish one-man rule.
# ---------------------------
# A snippet from the article: The International Center of Photography’s summer exhibition features the work of 75 professionals for Magnum Photos, including Henri Cartier-Bresson.
# ---------------------------
# A snippet from the article: Mr. Harvey, among the most prolific mass murderers in United States history, confessed to killing 37 people, mostly hospital patients, over two decades in Ohio and Kentucky.
# ---------------------------
# A snippet from the article: Vanessa Friedman takes us behind an unmarked door to find a supersecret collaboration between Louis Vuitton and the artist Jeff Koons.
# ---------------------------
# A snippet from the article: In “Tell Me How It Ends,” Valeria Luiselli describes her encounters with undocumented migrant children and the circumstances that produced them.
# ---------------------------
# A snippet from the article: John Curry witnessed an apparition of saints in Ireland. He was buried on Long Island, but will be reburied in Manhattan.
# ---------------------------
# A snippet from the article: The missile launched on Sunday could not reach American bases in Guam, South Korean officials said, but the test appeared to have provided useful data.
# ---------------------------
# A snippet from the article: John Curry witnessed an apparition of saints in Ireland. He was buried on Long Island, but will be reburied in Manhattan.
# ---------------------------
# A snippet from the article: The vice president, Gen. Abdul Rashid Dostum, left in what Afghan and Western officials suggested could be another long exile for the former warlord.
# ---------------------------
# A snippet from the article: With deputies in ski masks and tough talk from the Lake County sheriff, a video elicited complaints that it militarized the police — but it also has support in the community.
# ---------------------------
# A snippet from the article: Was Stalin’s terror his doing alone? Or was mass violence an intrinsic part of Bolshevism? An answer in the Soviet archives.
# ---------------------------
# A snippet from the article: The star conductor issued his strongest statement yet about the crisis in his native country after a young musician was reportedly killed in street protests.
# ---------------------------
# A snippet from the article: Never eat oysters in months that don’t have the letter “r”? With proper precautions, you can ignore that adage.
# ---------------------------
# A snippet from the article: Claire Cameron’s new novel, “The Last Neanderthal,” imagines the life of a Cro-Magnon girl struggling to survive some 40,000 years ago.
# ---------------------------
# A snippet from the article: Not only is the movement against Trump still strong, but it appears to be getting stronger.
# ---------------------------
# A snippet from the article: Peter Manning, a clothing brand for men 5-foot-8 and under, has opened its first store in Manhattan.
# ---------------------------
# A snippet from the article: Fighting food waste, a British team enlists a Bronx brewery, and plans to sell the beer in stores, restaurants and bars.
# ---------------------------
# A snippet from the article: Mazda’s consummate sports car adds a stylish retractable roof. It keeps the frisky driving attitude but can feel claustrophobic.
# ---------------------------
# A snippet from the article: James Forman Jr.’s “Locking Up Our Own” and Chris Hayes’s “A Colony in a Nation” compel readers to wrestle with very tough questions about racism, inequality and punishment.
# ---------------------------
# A snippet from the article: The parent of the messaging app Snapchat reported earnings that missed Wall Street expectations in almost every regard.
# ---------------------------
# A snippet from the article: Thomas Rainer’s work is a revelation: It turns out that plants are social, and have a body language that explains what they need.
# ---------------------------
# A snippet from the article: Details were still emerging, but it appeared to have been the single deadliest known attack on an Afghan military base since the war began.
# ---------------------------
# A snippet from the article: Men who shave often may be wasting their time. Research suggests that both women and men prefer men who sport at least some amount of facial hair.
# ---------------------------
# A snippet from the article: Some of the most beautiful tulips ever grown result from a virus that makes the flowers wilt early, and for that reason they are illegal in some places.
# ---------------------------
# A snippet from the article: Tired of political news? We found fascinating articles about hula girls, the world’s worst director and subway accessibility.
# ---------------------------
# A snippet from the article: The defining sartorial style of the 2010s has begun to emerge.
# ---------------------------
